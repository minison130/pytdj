# %%
import re

import numpy

import chainer
import chainer.functions as F
import chainer.links as L
from chainer import training
from chainer.training import extensions
import chainerx

# %%
# Network definition
class MLP(chainer.Chain):

    def __init__(self, n_units, n_out):
        super(MLP, self).__init__()
        with self.init_scope():
            # the size of the inputs to each layer will be inferred
            self.l1 = L.Linear(None, n_units)  # n_in -> n_units
            self.l2 = L.Linear(None, n_units)  # n_units -> n_units
            self.l3 = L.Linear(None, n_out)  # n_units -> n_out

    def forward(self, x):
        h1 = F.relu(self.l1(x))
        h2 = F.relu(self.l2(h1))
        return self.l3(h2)

# %%
def parse_device(args):
    gpu = None
    if args.gpu is not None:
        gpu = args.gpu
    elif re.match(r'(-|\+|)[0-9]+$', args.device):
        gpu = int(args.device)

    if gpu is not None:
        if gpu < 0:
            return chainer.get_device(numpy)
        else:
            import cupy
            return chainer.get_device((cupy, gpu))

    return chainer.get_device(args.device)

# %%
# JupyterはArgmentPraserが使えないので、Dummyクラスで定義する
class ArgDummy:
    def __init__(self):
        self.batchsize = 100  # Mumber of images in each mini-batch
        self.epoch = 10  # Number of sweeps over the dataset to train
        self.frequency = -1  # Frequency of taking a snapshot
        self.device = "-1"  # Device specifier. Either ChainerX device
        self.out = "result"  # Directory to output the result
        self.resume = False  # Resume the training from snapshot
        self.unit = 1000  # Number of units
        self.plot = False  # Disable PlotReport extension
        self.gpu = -1 # GPU ID (negative value indicates CPU)
        
args = ArgDummy()
device = parse_device(args)

# Set up a neural network to train
# Classifier reports softmax cross entropy loss and accuracy at every
# iteration, which will be used by the PrintReport extension below.
model = L.Classifier(MLP(args.unit, 10))
model.to_device(device)
device.use()

# Setup an optimizer
optimizer = chainer.optimizers.Adam()
optimizer.setup(model)

# Load the MNIST dataset
train, test = chainer.datasets.get_mnist()

train_iter = chainer.iterators.SerialIterator(train, args.batchsize)
test_iter = chainer.iterators.SerialIterator(test, args.batchsize,
                                                repeat=False, shuffle=False)

# Set up a trainer
updater = training.updaters.StandardUpdater(
    train_iter, optimizer, device=device)
trainer = training.Trainer(updater, (args.epoch, 'epoch'), out=args.out)

# Evaluate the model with the test dataset for each epoch
trainer.extend(extensions.Evaluator(test_iter, model, device=device))

# Dump a computational graph from 'loss' variable at the first iteration
# The "main" refers to the target link of the "main" optimizer.
# TODO(niboshi): Temporarily disabled for chainerx. Fix it.
if device.xp is not chainerx:
    trainer.extend(extensions.dump_graph('main/loss'))

# Take a snapshot for each specified epoch
frequency = args.epoch if args.frequency == -1 else max(1, args.frequency)
trainer.extend(extensions.snapshot(), trigger=(frequency, 'epoch'))

# Write a log of evaluation statistics for each epoch
trainer.extend(extensions.LogReport())

# Save two plot images to the result dir
if args.plot and extensions.PlotReport.available():
    trainer.extend(
        extensions.PlotReport(['main/loss', 'validation/main/loss'], 'epoch', file_name='loss.png'))
    trainer.extend(
        extensions.PlotReport(['main/accuracy', 'validation/main/accuracy'], 'epoch', file_name='accuracy.png'))
    
# Print selected entries of the log to stdout
# Here "main" refers to the target link of the "main" optimizer again, and
# "validation" refers to the default name of the Evaluator extension.
# Entries other than 'epoch' are reported by the Classifier link, called by
# either the updater or the evaluator.
trainer.extend(extensions.PrintReport(
    ['epoch', 'main/loss', 'validation/main/loss', 'main/accuracy', 'validation/main/accuracy', 'elapsed_time']))

# Print a progress bar to stdout
trainer.extend(extensions.ProgressBar())

if args.resume:
    # Resume from a snapshot
    chainer.serializers.load_npz(args.resume, trainer)

# Run the training
trainer.run()
# Out:
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  1.67%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 10 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [#.................................................]  3.33%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 10 epochs
#     2.7865 iters/sec. Estimated time to finish: 0:34:41.474823.
#      total [##................................................]  5.00%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 10 epochs
#     2.6184 iters/sec. Estimated time to finish: 0:36:16.925105.
#      total [###...............................................]  6.67%
# this epoch [#################################.................] 66.67%
#        400 iter, 0 epoch / 10 epochs
#     2.5643 iters/sec. Estimated time to finish: 0:36:23.857220.
#      total [####..............................................]  8.33%
# this epoch [#########################################.........] 83.33%
#        500 iter, 0 epoch / 10 epochs
#     2.5166 iters/sec. Estimated time to finish: 0:36:25.458219.
# 1           0.191474    0.090481              0.942767       0.9729                    257.153
#      total [#####.............................................] 10.00%
# this epoch [..................................................]  0.00%
#        600 iter, 1 epoch / 10 epochs
#      2.276 iters/sec. Estimated time to finish: 0:39:32.575827.
#      total [#####.............................................] 11.67%
# this epoch [########..........................................] 16.67%
#        700 iter, 1 epoch / 10 epochs
#     2.2895 iters/sec. Estimated time to finish: 0:38:34.930724.
#      total [######............................................] 13.33%
# this epoch [################..................................] 33.33%
#        800 iter, 1 epoch / 10 epochs
#     2.3095 iters/sec. Estimated time to finish: 0:37:31.602080.
#      total [#######...........................................] 15.00%
# this epoch [#########################.........................] 50.00%
#        900 iter, 1 epoch / 10 epochs
#     2.3242 iters/sec. Estimated time to finish: 0:36:34.256258.
#      total [########..........................................] 16.67%
# this epoch [#################################.................] 66.67%
#       1000 iter, 1 epoch / 10 epochs
#     2.3643 iters/sec. Estimated time to finish: 0:35:14.763806.
#      total [#########.........................................] 18.33%
# this epoch [#########################################.........] 83.33%
#       1100 iter, 1 epoch / 10 epochs
#     2.3931 iters/sec. Estimated time to finish: 0:34:07.535452.
# 2           0.0727312   0.0659402             0.977183       0.9786                    511.004
#      total [##########........................................] 20.00%
# this epoch [..................................................]  0.00%
#       1200 iter, 2 epoch / 10 epochs
#      2.323 iters/sec. Estimated time to finish: 0:34:26.315634.
#      total [##########........................................] 21.67%
# this epoch [########..........................................] 16.67%
#       1300 iter, 2 epoch / 10 epochs
#      2.348 iters/sec. Estimated time to finish: 0:33:21.725805.
#      total [###########.......................................] 23.33%
# this epoch [################..................................] 33.33%
#       1400 iter, 2 epoch / 10 epochs
#     2.3757 iters/sec. Estimated time to finish: 0:32:16.232987.
#      total [############......................................] 25.00%
# this epoch [#########################.........................] 50.00%
#       1500 iter, 2 epoch / 10 epochs
#     2.4001 iters/sec. Estimated time to finish: 0:31:14.957917.
#      total [#############.....................................] 26.67%
# this epoch [#################################.................] 66.67%
#       1600 iter, 2 epoch / 10 epochs
#      2.422 iters/sec. Estimated time to finish: 0:30:16.709353.
#      total [##############....................................] 28.33%
# this epoch [#########################################.........] 83.33%
#       1700 iter, 2 epoch / 10 epochs
#     2.4379 iters/sec. Estimated time to finish: 0:29:23.833705.
# 3           0.0504397   0.0794914             0.98345        0.9772                    749.293
#      total [###############...................................] 30.00%
# this epoch [..................................................]  0.00%
#       1800 iter, 3 epoch / 10 epochs
#     2.3882 iters/sec. Estimated time to finish: 0:29:18.615733.
#      total [###############...................................] 31.67%
# this epoch [########..........................................] 16.67%
#       1900 iter, 3 epoch / 10 epochs
#     2.3988 iters/sec. Estimated time to finish: 0:28:29.191060.
#      total [################..................................] 33.33%
# this epoch [################..................................] 33.33%
#       2000 iter, 3 epoch / 10 epochs
#     2.4157 iters/sec. Estimated time to finish: 0:27:35.851084.
#      total [#################.................................] 35.00%
# this epoch [#########################.........................] 50.00%
#       2100 iter, 3 epoch / 10 epochs
#      2.431 iters/sec. Estimated time to finish: 0:26:44.262974.
#      total [##################................................] 36.67%
# this epoch [#################################.................] 66.67%
#       2200 iter, 3 epoch / 10 epochs
#     2.4452 iters/sec. Estimated time to finish: 0:25:54.078085.
#      total [###################...............................] 38.33%
# this epoch [#########################################.........] 83.33%
#       2300 iter, 3 epoch / 10 epochs
#     2.4581 iters/sec. Estimated time to finish: 0:25:05.249367.
# 4           0.036358    0.0802271             0.988467       0.976                     993.811
#      total [####################..............................] 40.00%
# this epoch [..................................................]  0.00%
#       2400 iter, 4 epoch / 10 epochs
#      2.405 iters/sec. Estimated time to finish: 0:24:56.866159.
#      total [####################..............................] 41.67%
# this epoch [########..........................................] 16.67%
#       2500 iter, 4 epoch / 10 epochs
#     2.4083 iters/sec. Estimated time to finish: 0:24:13.302161.
#      total [#####################.............................] 43.33%
# this epoch [################..................................] 33.33%
#       2600 iter, 4 epoch / 10 epochs
#     2.4082 iters/sec. Estimated time to finish: 0:23:31.854840.
#      total [######################............................] 45.00%
# this epoch [#########################.........................] 50.00%
#       2700 iter, 4 epoch / 10 epochs
#     2.4161 iters/sec. Estimated time to finish: 0:22:45.814849.
#      total [#######################...........................] 46.67%
# this epoch [#################################.................] 66.67%
#       2800 iter, 4 epoch / 10 epochs
#     2.4256 iters/sec. Estimated time to finish: 0:21:59.279178.
#      total [########################..........................] 48.33%
# this epoch [#########################################.........] 83.33%
#       2900 iter, 4 epoch / 10 epochs
#     2.4363 iters/sec. Estimated time to finish: 0:21:12.430599.
# 5           0.02667     0.0728067             0.991817       0.9808                    1241.42
#      total [#########################.........................] 50.00%
# this epoch [..................................................]  0.00%
#       3000 iter, 5 epoch / 10 epochs
#     2.4088 iters/sec. Estimated time to finish: 0:20:45.459173.
#      total [#########################.........................] 51.67%
# this epoch [########..........................................] 16.67%
#       3100 iter, 5 epoch / 10 epochs
#     2.4168 iters/sec. Estimated time to finish: 0:19:59.955247.
#      total [##########################........................] 53.33%
# this epoch [################..................................] 33.33%
#       3200 iter, 5 epoch / 10 epochs
#     2.4264 iters/sec. Estimated time to finish: 0:19:13.952693.
#      total [###########################.......................] 55.00%
# this epoch [#########################.........................] 50.00%
#       3300 iter, 5 epoch / 10 epochs
#     2.4359 iters/sec. Estimated time to finish: 0:18:28.429484.
#      total [############################......................] 56.67%
# this epoch [#################################.................] 66.67%
#       3400 iter, 5 epoch / 10 epochs
#     2.4448 iters/sec. Estimated time to finish: 0:17:43.491299.
#      total [#############################.....................] 58.33%
# this epoch [#########################################.........] 83.33%
#       3500 iter, 5 epoch / 10 epochs
#     2.4531 iters/sec. Estimated time to finish: 0:16:59.111812.
# 6           0.0227747   0.0821718             0.992667       0.9797                    1477.3
#      total [##############################....................] 60.00%
# this epoch [..................................................]  0.00%
#       3600 iter, 6 epoch / 10 epochs
#     2.4309 iters/sec. Estimated time to finish: 0:16:27.305763.
#      total [##############################....................] 61.67%
# this epoch [########..........................................] 16.67%
#       3700 iter, 6 epoch / 10 epochs
#     2.4391 iters/sec. Estimated time to finish: 0:15:42.959360.
#      total [###############################...................] 63.33%
# this epoch [################..................................] 33.33%
#       3800 iter, 6 epoch / 10 epochs
#      2.447 iters/sec. Estimated time to finish: 0:14:59.070664.
#      total [################################..................] 65.00%
# this epoch [#########################.........................] 50.00%
#       3900 iter, 6 epoch / 10 epochs
#     2.4541 iters/sec. Estimated time to finish: 0:14:15.725171.
#      total [#################################.................] 66.67%
# this epoch [#################################.................] 66.67%
#       4000 iter, 6 epoch / 10 epochs
#     2.4604 iters/sec. Estimated time to finish: 0:13:32.869286.
#      total [##################################................] 68.33%
# this epoch [#########################################.........] 83.33%
#       4100 iter, 6 epoch / 10 epochs
#     2.4671 iters/sec. Estimated time to finish: 0:12:50.128121.
# 7           0.020697    0.0855279             0.993733       0.979                     1712.78
#      total [###################################...............] 70.00%
# this epoch [..................................................]  0.00%
#       4200 iter, 7 epoch / 10 epochs
#     2.4473 iters/sec. Estimated time to finish: 0:12:15.497229.
#      total [###################################...............] 71.67%
# this epoch [########..........................................] 16.67%
#       4300 iter, 7 epoch / 10 epochs
#     2.4539 iters/sec. Estimated time to finish: 0:11:32.784686.
#      total [####################################..............] 73.33%
# this epoch [################..................................] 33.33%
#       4400 iter, 7 epoch / 10 epochs
#     2.4594 iters/sec. Estimated time to finish: 0:10:50.568157.
#      total [#####################################.............] 75.00%
# this epoch [#########################.........................] 50.00%
#       4500 iter, 7 epoch / 10 epochs
#     2.4647 iters/sec. Estimated time to finish: 0:10:08.600475.
#      total [######################################............] 76.67%
# this epoch [#################################.................] 66.67%
#       4600 iter, 7 epoch / 10 epochs
#     2.4694 iters/sec. Estimated time to finish: 0:09:26.940060.
#      total [#######################################...........] 78.33%
# this epoch [#########################################.........] 83.33%
#       4700 iter, 7 epoch / 10 epochs
#     2.4728 iters/sec. Estimated time to finish: 0:08:45.709205.
# 8           0.0191107   0.0877083             0.993733       0.9781                    1952.38
#      total [########################################..........] 80.00%
# this epoch [..................................................]  0.00%
#       4800 iter, 8 epoch / 10 epochs
#     2.4544 iters/sec. Estimated time to finish: 0:08:08.910060.
#      total [########################################..........] 81.67%
# this epoch [########..........................................] 16.67%
#       4900 iter, 8 epoch / 10 epochs
#     2.4592 iters/sec. Estimated time to finish: 0:07:27.297454.
#      total [#########################################.........] 83.33%
# this epoch [################..................................] 33.33%
#       5000 iter, 8 epoch / 10 epochs
#     2.4636 iters/sec. Estimated time to finish: 0:06:45.904013.
#      total [##########################################........] 85.00%
# this epoch [#########################.........................] 50.00%
#       5100 iter, 8 epoch / 10 epochs
#     2.4682 iters/sec. Estimated time to finish: 0:06:04.642012.
#      total [###########################################.......] 86.67%
# this epoch [#################################.................] 66.67%
#       5200 iter, 8 epoch / 10 epochs
#     2.4733 iters/sec. Estimated time to finish: 0:05:23.457885.
#      total [############################################......] 88.33%
# this epoch [#########################################.........] 83.33%
#       5300 iter, 8 epoch / 10 epochs
#      2.478 iters/sec. Estimated time to finish: 0:04:42.489446.
# 9           0.0179863   0.0713655             0.99425        0.9821                    2190.02
#      total [#############################################.....] 90.00%
# this epoch [..................................................]  0.00%
#       5400 iter, 9 epoch / 10 epochs
#     2.4622 iters/sec. Estimated time to finish: 0:04:03.683624.
#      total [#############################################.....] 91.67%
# this epoch [########..........................................] 16.67%
#       5500 iter, 9 epoch / 10 epochs
#      2.467 iters/sec. Estimated time to finish: 0:03:22.676633.
#      total [##############################################....] 93.33%
# this epoch [################..................................] 33.33%
#       5600 iter, 9 epoch / 10 epochs
#     2.4715 iters/sec. Estimated time to finish: 0:02:41.843066.
#      total [###############################################...] 95.00%
# this epoch [#########################.........................] 50.00%
#       5700 iter, 9 epoch / 10 epochs
#      2.476 iters/sec. Estimated time to finish: 0:02:01.162886.
#      total [################################################..] 96.67%
# this epoch [#################################.................] 66.67%
#       5800 iter, 9 epoch / 10 epochs
#     2.4803 iters/sec. Estimated time to finish: 0:01:20.633929.
#      total [#################################################.] 98.33%
# this epoch [#########################################.........] 83.33%
#       5900 iter, 9 epoch / 10 epochs
#     2.4841 iters/sec. Estimated time to finish: 0:00:40.256365.
# 10          0.0139329   0.0796676             0.9955         0.9805                    2427.01
#      total [##################################################] 100.00%
# this epoch [..................................................]  0.00%
#       6000 iter, 10 epoch / 10 epochs
#     2.4691 iters/sec. Estimated time to finish: 0:00:00.
